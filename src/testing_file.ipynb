# %%
from ultralytics import YOLO
import torch

# Load model
model = YOLO("yolo11x.pt")

# Force model to GPU
model.to("cuda")

print("Torch CUDA available:", torch.cuda.is_available())
print("YOLO device:", model.device)
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch CUDA available: True
# YOLO device: cuda:0
# GPU name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
from helper_functions import predict_material

import cv2

frame = cv2.imread(r"C:\Users\A8000\Downloads\Data_science\CV_parallel_proc\output_frames\frame_1_20260114_124456_979485.jpg")
cls, prob = predict_material(frame)

print("Class:", cls)
print("Confidence:", prob)
# Out:
# Class: 0
# Confidence: 0.0008548080804757774
